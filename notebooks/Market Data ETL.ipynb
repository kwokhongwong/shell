# %% [markdown]
# # Market Data ETL & Query
#
# This notebook demonstrates output from a toy implementation, it shows market data load required for Black 76 Options pricing for `BRENT`, `WTI` & `HH` (from multiple exchanges)
#
# We use the `RESTClient` to persist and query market data, `LocalClient` can also be used for local development - new data ETL can be easily created by extending
#
# `market.etl_adapter.BaseETLAdapter`
#
# and implementing the `transform(self, url: str, params: dict)` method
#
# Or you can simply munge your market data and use the `RestClient.save` endpoint
#
# Below we see the various data adapter implementations to support ETL across a few exchanges:
# - Some raw market files are held locally given account access restrictions etc
# - Use of concurrent compute is used below for the Quandl OWF Implied Vol Models, given abundance of files required - in reality this would be implemented in a production setting using a robust DAG scheduler e.g. Luigi, Apache Airflow etc
#
# A rudimentary symbology is assumed, as described in the Design/Architecture notes, this is an area for further work

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../'))

from analytics.constants import CONTRACT_EXCHANGE_MAP, FUTURES_DELIVERY_MAP
from api import RestClient as c
from market.etl_option_expiries import CMEOptionExpiriesAdapter, ICEOptionExpiriesAdapter
from market.etl_yield_curve import FEDUSTAdapter
# Out:
# ***** Shell Trading API *****
# TRADE_DATE = 2022-12-09
# MARKET_DATE = 2022-12-09
# ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# REST_API_URL = http://127.0.0.1:5000

# %% [markdown]
# A separate abstracted Data persist/query API exists for use by ETL adapters - data is saved as parquet files for this toy implementation, it is trivial to extend this to support various types of SQL/NoSql datastores etc
#
# See `market.datastore_adapter.DataAPI` for more details

# %%
# ICE EU Style Brent Option Expiries
ICEOptionExpiriesAdapter(
    symbol='CALENDAR_OPTION_BRENT', url='ProductSpecExpiryDates_BRENT_OPTIONS.csv'
).run(save=True).head()
# Out:
# Symbol CALENDAR_OPTION_BRENT saved successfully.
#       EXPIRATION_DATE
# G2023      2022-12-22
# H2023      2023-01-26
# J2023      2023-02-23
# K2023      2023-03-28
# M2023      2023-04-25

# %% [markdown]
# You can see the transform code like so ICEOptionExpiriesAdapter.transform?? e.g.
#
# Signature: ICEOptionExpiriesAdapter.transform(self, url: str, params: dict) -> pandas.core.frame.DataFrame
# Docstring: <no docstring>
# Source:
#     def transform(self, url: str, params: dict) -> pd.DataFrame:
#         assert url
#
#         dataframe = pd.read_csv(url)
#         dataframe.index = [
#             ''.join((FUTURES_DELIVERY_MAP[contract[2:5].upper()], '20', contract[5:-1]))
#             for contract in dataframe.index
#         ]
#         dataframe = dataframe[['OPTIONS FTD']]
#         dataframe.columns = ['EXPIRATION_DATE']
#         dataframe['EXPIRATION_DATE'] = dataframe['EXPIRATION_DATE'].astype(np.datetime64)
#
#         return dataframe
# File:      c:\users\magicmonk\pycharmprojects\shell\market\etl_option_expiries.py
# Type:      function

# %% [markdown]
# We can use the RestClient API to query the saved data like so...

# %%
c.data(symbol='CALENDAR_OPTION_BRENT').head()
# Out:
#       EXPIRATION_DATE
# G2023      2022-12-22
# H2023      2023-01-26
# J2023      2023-02-23
# K2023      2023-03-28
# M2023      2023-04-25

# %%
# ICE EU Style WTI Option Expiries
ICEOptionExpiriesAdapter(
    symbol='CALENDAR_OPTION_WTI', url='ProductSpecExpiryDates_WTI_OPTIONS.csv'
).run(save=True).head()
# Out:
# Symbol CALENDAR_OPTION_WTI saved successfully.
#       EXPIRATION_DATE
# F2023      2022-12-15
# G2023      2023-01-17
# H2023      2023-02-15
# J2023      2023-03-16
# K2023      2023-04-17

# %%
# CME EU Style HH Option Expiries
CMEOptionExpiriesAdapter(
    symbol='CALENDAR_OPTION_HH', url='product-calendar_HH_OPTIONS.xls'
).run(save=True).head()
# Out:
# Symbol CALENDAR_OPTION_HH saved successfully.
#       EXPIRATION_DATE
# F2023      2022-12-27
# G2023      2023-01-26
# H2023      2023-02-23
# J2023      2023-03-28
# K2023      2023-04-25

# %%
# Fed Reserve US Treasury Constant Maturity
FEDUSTAdapter(
    symbol='RIFLGFC', url='FRB_H15.csv'
).run(save=True).head()
# Out:
# Symbol RIFLGFC saved successfully.
#              RIFLGFCM01_N.B  RIFLGFCM03_N.B  RIFLGFCM06_N.B  RIFLGFCY01_N.B  \
# Time Period
# 1962-01-02              NaN             NaN             NaN        0.031944
# 1962-01-03              NaN             NaN             NaN        0.032140
# 1962-01-04              NaN             NaN             NaN        0.032140
# 1962-01-05              NaN             NaN             NaN        0.032337
# 1962-01-08              NaN             NaN             NaN        0.032829
#
#              RIFLGFCY02_N.B  RIFLGFCY03_N.B  RIFLGFCY05_N.B  RIFLGFCY07_N.B  \
# Time Period
# 1962-01-02              NaN        0.036662        0.038428             NaN
# 1962-01-03              NaN        0.036662        0.038330             NaN
# 1962-01-04              NaN        0.036564        0.038232             NaN
# 1962-01-05              NaN        0.036760        0.038526             NaN
# 1962-01-08              NaN        0.036760        0.038723             NaN
#
#              RIFLGFCY10_N.B  RIFLGFCY20_N.B  RIFLGFCY30_N.B
# Time Period
# 1962-01-02         0.040193        0.040291             NaN
# 1962-01-03         0.039899        0.040291             NaN
# 1962-01-04         0.039507        0.040193             NaN
# 1962-01-05         0.039801        0.040291             NaN
# 1962-01-08         0.039899        0.040390             NaN

# %%
# Quandl OWF Option Implied Vols
CONTRACT_EXCHANGE_MAP
# Out:
# {('BRENT', 'ICE'): ('B', 'B', 1000),
#  ('WTI', 'NYM'): ('CL', 'CL', 1000),
#  ('WTI', 'ICE'): ('T', 'T', 1000),
#  ('HH', 'NYM'): ('NG', 'NG', 10000)}

# %% [markdown]
# Here we make use of `ray` multi-processing to speed up market data ETL for OptionWorks Futures (OWF) Implied Vol Model data

# %%
import ray

ray.init()
# Out:
# 2022-12-17 01:55:36,573	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8266
# RayContext(dashboard_url='127.0.0.1:8266', python_version='3.9.15', ray_version='2.2.0', ray_commit='b6af0887ee5f2e460202133791ad941a41f15beb', address_info={'node_ip_address': '127.0.0.1', 'raylet_ip_address': '127.0.0.1', 'redis_address': None, 'object_store_address': 'tcp://127.0.0.1:65517', 'raylet_socket_name': 'tcp://127.0.0.1:65467', 'webui_url': '127.0.0.1:8266', 'session_dir': 'C:\\Users\\MAGICM~1\\AppData\\Local\\Temp\\ray\\session_2022-12-17_01-55-34_552620_18520', 'metrics_export_port': 65451, 'gcs_address': '127.0.0.1:65491', 'address': '127.0.0.1:65491', 'dashboard_agent_listen_port': 52365, 'node_id': 'afb1b4aa2073929f0446e76525f215dacc7e18992bb9dec5beb7b756'})

# %%
# %%time

@ray.remote
def load_quandl_owf_implied_vols(
    contract: str,
    exchange_code: str,
    futures_code: str,
    options_code: str,
    year: str,
    month: str,
    url: str,
    save: bool,
    expiration: str,
    python_path: str
):
    assert contract
    assert exchange_code
    assert futures_code
    assert options_code
    assert year
    assert month
    assert url
    assert expiration
    assert python_path

    import sys
    sys.path.insert(0, os.path.abspath(python_path))
    
    from market.etl_implied_vols import QuandlOWFImpliedVolsAdapter
    
    params = {
        'EXCHANGE_CODE': exchange_code,
        'FUTURES_CODE': futures_code,
        'OPTIONS_CODE': options_code,
        'YEAR': year,
        'MONTH': month
    }
    
    symbol = f'{contract}_{exchange_code}_{futures_code}_{options_code}_{expiration}_IVM'

    try:
        return QuandlOWFImpliedVolsAdapter(
            symbol=symbol,
            url=url,
            params=params
        ).run(save=save)
    except:
        return

ray_ids = []
url = f'https://data.nasdaq.com/api/v3/datasets/OWF'
python_path = os.path.sep.join((os.getcwd().split(os.path.sep)[:-1]))
for (contract, exchange_code), (futures_code, options_code, __) in CONTRACT_EXCHANGE_MAP.items():

    for year in ('2022', '2023', '2024', '2025', '2026', '2027', '2028', '2029', '2030'):

        for month in ('JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'):
            
            expiration = f'{FUTURES_DELIVERY_MAP[month]}{year}'
            ray_ids.append(
                load_quandl_owf_implied_vols.remote(
                    contract=contract,
                    exchange_code=exchange_code,
                    futures_code=futures_code,
                    options_code=options_code,
                    year=year,
                    month=month,
                    url=url,
                    save=True,
                    expiration=expiration,
                    python_path=python_path
                )
            )

dataframes = ray.get(ray_ids)
# Out:
# (load_quandl_owf_implied_vols pid=23848) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=23848) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=23848) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=23848) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=23848) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=23848) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=4960) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=4960) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=4960) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=4960) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=4960) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=4960) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=7304) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=7304) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=7304) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=7304) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=7304) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=7304) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=20112) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=20112) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=20112) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=20112) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=20112) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=20112) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=6244) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=6244) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=6244) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=6244) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=6244) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=6244) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=22580) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=22580) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=22580) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=22580) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=22580) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=22580) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=8176) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=8176) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=8176) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=8176) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=8176) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=8176) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=12628) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=12628) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=12628) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=12628) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=12628) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=12628) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=4588) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=4588) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=4588) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=4588) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=4588) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=4588) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=6728) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=6728) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=6728) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=6728) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=6728) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=6728) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=10460) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=10460) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=10460) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=10460) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=10460) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=10460) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=12160) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=12160) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=12160) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=12160) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=12160) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=12160) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=1368) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=1368) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=1368) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=1368) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=1368) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=1368) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=14908) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=14908) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=14908) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=14908) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=14908) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=14908) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=20504) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=20504) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=20504) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=20504) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=20504) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=20504) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=9316) ***** Shell Trading API *****
# (load_quandl_owf_implied_vols pid=9316) TRADE_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=9316) MARKET_DATE = 2022-12-09
# (load_quandl_owf_implied_vols pid=9316) ROOT_PATH = C:\Users\magicmonk\PycharmProjects\shell
# (load_quandl_owf_implied_vols pid=9316) MARKET_DATA_PATH = C:\Users\magicmonk\PycharmProjects\shell\data
# (load_quandl_owf_implied_vols pid=9316) REST_API_URL = http://127.0.0.1:5000
# (load_quandl_owf_implied_vols pid=8176) Symbol BRENT_ICE_B_B_Q2022_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=10460) Symbol BRENT_ICE_B_B_G2022_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=20504) Symbol BRENT_ICE_B_B_X2022_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=20112) Symbol BRENT_ICE_B_B_K2022_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=4588) Symbol BRENT_ICE_B_B_N2022_IVM saved successfully.
# (load_quandl_owf_implied_vols pid
IVM saved successfully.
# (load_quandl_owf_implied_vols pid=22580) Symbol HH_NYM_NG_NG_K2029_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=6728) Symbol HH_NYM_NG_NG_U2028_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=7304) Symbol HH_NYM_NG_NG_J2029_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=20112) Symbol HH_NYM_NG_NG_F2029_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=4588) Symbol HH_NYM_NG_NG_H2029_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=4960) Symbol HH_NYM_NG_NG_U2029_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=1368) Symbol HH_NYM_NG_NG_Q2029_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=14908) Symbol HH_NYM_NG_NG_N2029_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=8176) Symbol HH_NYM_NG_NG_V2029_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=12628) Symbol HH_NYM_NG_NG_M2029_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=20504) Symbol HH_NYM_NG_NG_G2029_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=6244) Symbol HH_NYM_NG_NG_Z2028_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=9316) Symbol HH_NYM_NG_NG_Z2029_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=12160) Symbol HH_NYM_NG_NG_X2029_IVM saved successfully.
# (load_quandl_owf_implied_vols pid=10460) Symbol HH_NYM_NG_NG_X2028_IVM saved successfully.
# CPU times: total: 1.2 s
# Wall time: 26.7 s

# %%
dataframes[0].head()
# Out:
#                Future       AtM      RR25      RR10     Fly25     Fly10  \
# Date
# 2021-11-24  82.250000  0.448341  0.018241  0.023389  0.017135  0.066490
# 2021-11-23  82.309998  0.428443  0.011347  0.007743  0.014353  0.052090
# 2021-11-22  79.699997  0.415653 -0.057008 -0.130627  0.018386  0.074118
# 2021-11-19  78.889999  0.369036 -0.069729 -0.124354  0.011291  0.040405
# 2021-11-18  81.239998  0.323595 -0.032377 -0.064020  0.008199  0.032928
#
#                Beta1      Beta2       Beta3         Beta4         Beta5  \
# Date
# 2021-11-24  0.615285  75.819885 -417.058197 -11622.731445  57509.781250
# 2021-11-23  0.283453  32.990170 -143.453384  -3660.596436  10506.664062
# 2021-11-22 -1.088839  27.212183   47.159893  -1640.962280    127.687584
# 2021-11-19 -1.137661   9.490880   89.881325   -199.624283  -3864.152344
# 2021-11-18 -0.549235   8.666416   30.197849   -146.912750  -1009.595154
#
#                    Beta6  MinMoney  MaxMoney   DtE   DtT
# Date
# 2021-11-24  1.491270e+06 -0.058196  0.053267  0.85   6.0
# 2021-11-23  3.358728e+05 -0.079759  0.075331  1.85   7.0
# 2021-11-22  6.533061e+04 -0.119117  0.081875  2.85   8.0
# 2021-11-19 -4.288779e+03 -0.130331  0.092090  5.85  11.0
# 2021-11-18  1.469119e+03 -0.120742  0.096831  6.85  12.0
# (load_quandl_owf_implied_vols pid=22580) Symbol HH_NYM_NG_NG_F2030_IVM saved successfully.
# Exception in thread 2022-12-17 01:57:23,377	ERROR import_thread.py:75 -- ImportThread: <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.UNKNOWN
# 	details = "Stream removed"
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:127.0.0.1:65491 {created_time:"2022-12-17T01:57:23.336661737+00:00", grpc_status:2, grpc_message:"Stream removed"}"
# >
# ray_listen_error_messages:
# Traceback (most recent call last):
#   File "C:\Users\magicmonk\anaconda3\envs\shell\lib\threading.py", line 980, in _bootstrap_inner
# 2022-12-17 01:57:23,396	ERROR worker.py:813 -- print_logs: <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.UNKNOWN
# 	details = "Stream removed"
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:127.0.0.1:65491 {created_time:"2022-12-17T01:57:23.336678927+00:00", grpc_status:2, grpc_message:"Stream removed"}"
# >
